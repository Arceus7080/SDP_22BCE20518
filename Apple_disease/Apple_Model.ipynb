# %%
# !nvidia-smi
# Out:
# Thu Feb 12 21:29:28 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 591.86                 Driver Version: 591.86         CUDA Version: 13.1     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4050 ...  WDDM  |   00000000:01:00.0 Off |                  N/A |
# | N/A   39C    P8              2W /  140W |    4455MiB /   6141MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            2432    C+G   ...Browser\Application\brave.exe      N/A      |
# |    0   N/A  N/A           17124    C+G   ...Browser\Application\brave.exe      N/A      |
# |    0   N/A  N/A           27296      C   ...da3\envs\plant_env\python.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import (
    Conv2D, MaxPooling2D, Flatten, Dense, Dropout, 
    BatchNormalization, GlobalAveragePooling2D, Input,
    RandomFlip, RandomRotation, RandomZoom, RandomContrast, Rescaling, Resizing
)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import (
    EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
)
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import confusion_matrix,classification_report, f1_score
from tensorflow.keras.utils import image_dataset_from_directory
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.regularizers import l2
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sns

# %%
training_set = image_dataset_from_directory(
    'train',
    image_size=(224, 224),
    batch_size=16,
    color_mode='rgb',
    class_names=None,
    shuffle=True,
    seed = 123,
    validation_split=0.2,
    subset='training',
    interpolation='bilinear',
    follow_links=False,
    crop_to_aspect_ratio=False
)
# Out:
# Found 7771 files belonging to 4 classes.
# Using 6217 files for training.

# %%
validation_set = image_dataset_from_directory(
    'train',
    image_size=(224, 224),
    batch_size=16,
    color_mode='rgb',
    class_names=None,
    shuffle=True,
    seed = 123,
    validation_split=0.2,
    subset='validation',
    interpolation='bilinear',
    follow_links=False,
    crop_to_aspect_ratio=False
)
# Out:
# Found 7771 files belonging to 4 classes.
# Using 1554 files for validation.

# %%
test_set = image_dataset_from_directory(
    'valid',
    image_size=(224, 224),
    batch_size=16,
    color_mode='rgb',
    class_names=None,
    shuffle=False,
    validation_split=None,
    subset=None,
    interpolation='bilinear',
    follow_links=False,
    crop_to_aspect_ratio=False
)
# Out:
# Found 1943 files belonging to 4 classes.

# %%
class_names = training_set.class_names
print(class_names)
# Out:
# ['Apple___Apple_scab', 'Apple___Black_rot', 'Apple___Cedar_apple_rust', 'Apple___healthy']

# %%
import numpy as np

class_counts = np.zeros(len(class_names))

for images, labels in validation_set:
    for label in labels:
        class_counts[label.numpy()] += 1

for i, class_name in enumerate(class_names):
    print(f"{class_name}: {int(class_counts[i])}")
# Out:
# Apple___Apple_scab: 410
# Apple___Black_rot: 409
# Apple___Cedar_apple_rust: 341
# Apple___healthy: 394

# %%
import numpy as np

class_counts = np.zeros(len(class_names))

for images, labels in test_set:
    for label in labels:
        class_counts[label.numpy()] += 1

for i, class_name in enumerate(class_names):
    print(f"{class_name}: {int(class_counts[i])}")
# Out:
# Apple___Apple_scab: 504
# Apple___Black_rot: 497
# Apple___Cedar_apple_rust: 440
# Apple___healthy: 502

# %%
print(training_set)
print(validation_set)
print(test_set)
# Out:
# <BatchDataset element_spec=(TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <BatchDataset element_spec=(TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <BatchDataset element_spec=(TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
AUTOTUNE = tf.data.AUTOTUNE
training_set = training_set.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
validation_set = validation_set.cache().prefetch(buffer_size=AUTOTUNE)
test_set = test_set.cache().prefetch(buffer_size=AUTOTUNE)

# %%
num_classes = len(class_names)
input_shape = (224, 224, 3)
    
base_model = MobileNetV2(
    input_shape=input_shape,
    include_top=False,
    weights='imagenet',  
    alpha=1.0 
)

base_model.trainable = False

inputs = Input(shape=input_shape)
    
x = tf.keras.applications.mobilenet_v2.preprocess_input(inputs)
    
x = base_model(x, training=False)
x = GlobalAveragePooling2D()(x)
x = BatchNormalization()(x)
x = Dropout(0.3)(x)
    
x = Dense(128, activation='relu', kernel_regularizer=l2(0.001))(x)
x = BatchNormalization()(x)
x = Dropout(0.2)(x)
    
outputs = Dense(num_classes, activation='softmax', dtype='float32', name='predictions')(x)
    
model = Model(inputs, outputs, name='MobileNetV2_AppleDisease')

# %%
model.summary()
# Out:
# Model: "MobileNetV2_AppleDisease"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.math.truediv_1 (TFOpLamb  (None, 224, 224, 3)      0
#  da)
#
#  tf.math.subtract_1 (TFOpLam  (None, 224, 224, 3)      0
#  bda)
#
#  mobilenetv2_1.00_224 (Funct  (None, 7, 7, 1280)       2257984
#  ional)
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  batch_normalization (BatchN  (None, 1280)             5120
#  ormalization)
#
#  dropout (Dropout)           (None, 1280)              0
#
#  dense (Dense)               (None, 128)               163968
#
#  batch_normalization_1 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  predictions (Dense)         (None, 4)                 516
#
# =================================================================
# Total params: 2,428,100
# Trainable params: 167,300
# Non-trainable params: 2,260,800
# _________________________________________________________________

# %%
model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss=SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)

# %%
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=15,
    restore_best_weights=True,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    min_lr=1e-7,
    verbose=1
)

checkpoint = ModelCheckpoint(
    'Apple_custom_cnn_best_final.keras',
    monitor='val_accuracy',
    save_best_only=True,
    verbose=1
)

callbacks = [early_stop, reduce_lr, checkpoint]

# %%
training_history = model.fit(
    training_set,
    validation_data=validation_set,
    epochs=30,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/30
# 386/389 [============================>.] - ETA: 0s - loss: 0.8251 - accuracy: 0.7768
# Epoch 1: val_accuracy improved from -inf to 0.96847, saving model to Apple_custom_cnn_best_final.keras
# 389/389 [==============================] - 14s 26ms/step - loss: 0.8221 - accuracy: 0.7777 - val_loss: 0.3583 - val_accuracy: 0.9685 - lr: 1.0000e-04
# Epoch 2/30
# 389/389 [==============================] - ETA: 0s - loss: 0.4464 - accuracy: 0.9246
# Epoch 2: val_accuracy improved from 0.96847 to 0.97876, saving model to Apple_custom_cnn_best_final.keras
# 389/389 [==============================] - 9s 23ms/step - loss: 0.4464 - accuracy: 0.9246 - val_loss: 0.3059 - val_accuracy: 0.9788 - lr: 1.0000e-04
# Epoch 3/30
# 389/389 [==============================] - ETA: 0s - loss: 0.3882 - accuracy: 0.9410
# Epoch 3: val_accuracy improved from 0.97876 to 0.98649, saving model to Apple_custom_cnn_best_final.keras
# 389/389 [==============================] - 9s 23ms/step - loss: 0.3882 - accuracy: 0.9410 - val_loss: 0.2850 - val_accuracy: 0.9865 - lr: 1.0000e-04
# Epoch 4/30
# 388/389 [============================>.] - ETA: 0s - loss: 0.3506 - accuracy: 0.9548
# Epoch 4: val_accuracy improved from 0.98649 to 0.98777, saving model to Apple_custom_cnn_best_final.keras
# 389/389 [==============================] - 9s 23ms/step - loss: 0.3508 - accuracy: 0.9548 - val_loss: 0.2712 - val_accuracy: 0.9878 - lr: 1.0000e-04
# Epoch 5/30
# 388/389 [============================>.] - ETA: 0s - loss: 0.3151 - accuracy: 0.9684
# Epoch 5: val_accuracy improved from 0.98777 to 0.98906, saving model to Apple_custom_cnn_best_final.keras
# 389/389 [==============================] - 9s 23ms/step - loss: 0.3154 - accuracy: 0.9683 - val_loss: 0.2587 - val_accuracy: 0.9891 - lr: 1.0000e-04
# Epoch 6/30
# 387/389 [============================>.] - ETA: 0s - loss: 0.2953 - accuracy: 0.9756
# Epoch 6: val_accuracy did not improve from 0.98906
# 389/389 [==============================] - 9s 23ms/step - loss: 0.2951 - accuracy: 0.9757 - val_loss: 0.2502 - val_accuracy: 0.9891 - lr: 1.0000e-04
# Epoch 7/30
# 387/389 [============================>.] - ETA: 0s - loss: 0.2852 - accuracy: 0.9746
# Epoch 7: val_accuracy improved from 0.98906 to 0.98970, saving model to Apple_custom_cnn_best_final.keras
# 389/389 [==============================] - 9s 23ms/step - loss: 0.2850 - accuracy: 0.9746 - val_loss: 0.2426 - val_accuracy: 0.9897 - lr: 1.0000e-04
# Epoch 8/30
# 389/389 [==============================] - ETA: 0s - loss: 0.2668 - accuracy: 0.9820
# Epoch 8: val_accuracy improved from 0.98970 to 0.99035, saving model to Apple_custom_cnn_best_final.keras
# 389/389 [==============================] - 9s 23ms/step - loss: 0.2668 - accuracy: 0.9820 - val_loss: 0.2367 - val_accuracy: 0.9903 - lr: 1.0000e-04
# Epoch 9/30
# 387/389 [============================>.] - ETA: 0s - loss: 0.2543 - accuracy: 0.9825
# Epoch 9: val_accuracy improved from 0.99035 to 0.99228, saving model to Apple_custom_cnn_best_final.keras
# 389/389 [==============================] - 9s 23ms/step - loss: 0.2545 - accuracy: 0.9823 - val_loss: 0.2268 - val_accuracy: 0.9923 - lr: 1.0000e-04
# Epoch 10/30
# 389/389 [==============================] - ETA: 0s - loss: 0.2415 - accuracy: 0.9865
# Epoch 10: val_accuracy did not improve from 0.99228
# 389/389 [==============================] - 9s 23ms/step - loss: 0.2415 - accuracy: 0.9865 - val_loss: 0.2202 - val_accuracy: 0.9923 - lr: 1.0000e-04
# Epoch 11/30
# 389/389 [==============================] - ETA: 0s - loss: 0.2287 - accuracy: 0.9881
# Epoch 11: val_accuracy did not improve from 0.99228
# 389/389 [==============================] - 9s 22ms/step - loss: 0.2287 - accuracy: 0.9881 - val_loss: 0.2119 - val_accuracy: 0.9916 - lr: 1.0000e-04
# Epoch 12/30
# 387/389 [============================>.] - ETA: 0s - loss: 0.2207 - accuracy: 0.9895
# Epoch 12: val_accuracy improved from 0.99228 to 0.99357, saving model to Apple_custom_cnn_best_final.keras
# 389/389 [==============================] - 9s 22ms/step - loss: 0.2206 - accuracy: 0.9895 - val_loss: 0.2055 - val_accuracy: 0.9936 - lr: 1.0000e-04
# Epoch 13/30
# 389/389 [==============================] - ETA: 0s - loss: 0.2098 - accuracy: 0.9899
# Epoch 13: val_accuracy did not improve from 0.99357
# 389/389 [==============================] - 9s 22ms/step - loss: 0.2098 - accuracy: 0.9899 - val_loss: 0.1995 - val_accuracy: 0.9910 - lr: 1.0000e-04
# Epoch 14/30
# 387/389 [============================>.] - ETA: 0s - loss: 0.2022 - accuracy: 0.9908
# Epoch 14: val_accuracy did not improve from 0.99357
# 389/389 [==============================] - 9s 22ms/step - loss: 0.2021 - accuracy: 0.9908 - val_loss: 0.1944 - val_accuracy: 0.9903 - lr: 1.0000e-04
# Epoch 15/30
# 389/389 [==============================] - ETA: 0s - loss: 0.1943 - accuracy: 0.9907
# Epoch 15: val_accuracy did not improve from 0.99357
# 389/389 [==============================] - 9s 22ms/step - loss: 0.1943 - accuracy: 0.9907 - val_loss: 0.1870 - val_accuracy: 0.9910 - lr: 1.0000e-04
# Epoch 16/30
# 387/389 [============================>.] - ETA: 0s - loss: 0.1857 - accuracy: 0.9919
# Epoch 16: val_accuracy did not improve from 0.99357
# 389/389 [==============================] - 9s 22ms/step - loss: 0.1856 - accuracy: 0.9920 - val_loss: 0.1802 - val_accuracy: 0.9903 - lr: 1.0000e-04
# Epoch 17/30
# 388/389 [============================>.] - ETA: 0s - loss: 0.1749 - accuracy: 0.9942
# Epoch 17: val_accuracy improved from 0.99357 to 0.99421, saving model to Apple_custom_cnn_best_final.keras
# 389/389 [==============================] - 9s 22ms/step - loss: 0.1749 - accuracy: 0.9942 - val_loss: 0.1730 - val_accuracy: 0.9942 - lr: 1.0000e-04
# Epoch 18/30
# 389/389 [==============================] - ETA: 0s - loss: 0.1699 - accuracy: 0.9944
# Epoch 18: val_accuracy did not improve from 0.99421
# 389/389 [==============================] - 10s 25ms/step - loss: 0.1699 - accuracy: 0.9944 - val_loss: 0.1663 - val_accuracy: 0.9929 - lr: 1.0000e-04
# Epoch 19/30
# 387/389 [============================>.] - ETA: 0s - loss: 0.1619 - accuracy: 0.9945
# Epoch 19: val_accuracy did not improve from 0.99421
# 389/389 [==============================] - 10s 26ms/step - loss: 0.1618 - accuracy: 0.9945 - val_loss: 0.1604 - val_accuracy: 0.9929 - lr: 1.0000e-04
# Epoch 20/30
# 389/389 [==============================] - ETA: 0s - loss: 0.1538 - accuracy: 0.9965
# Epoch 20: val_accuracy did not improve from 0.99421
# 389/389 [==============================] - 9s 24ms/step - loss: 0.1538 - accuracy: 0.9965 - val_loss: 0.1538 - val_accuracy: 0.9942 - lr: 1.0000e-04
# Epoch 21/30
# 388/389 [============================>.] - ETA: 0s - loss: 0.1480 - accuracy: 0.9955
# Epoch 21: val_accuracy did not improve from 0.99421
# 389/389 [==============================] - 9s 24ms/step - loss: 0.1479 - accuracy: 0.9955 - val_loss: 0.1506 - val_accuracy: 0.9916 - lr: 1.0000e-04
# Epoch 22/30
# 389/389 [==============================] - ETA: 0s - loss: 0.1409 - accuracy: 0.9957
# Epoch 22: val_accuracy did not improve from 0.99421
# 389/389 [==============================] - 10s 24ms/step - loss: 0.1409 - accuracy: 0.9957 - val_loss: 0.1478 - val_accuracy: 0.9897 - lr: 1.0000e-04
# Epoch 23/30
# 387/389 [============================>.] - ETA: 0s - loss: 0.1332 - accuracy: 0.9964
# Epoch 23: val_accuracy did not improve from 0.99421
# 389/389 [==============================] - 10s 25ms/step - loss: 0.1331 - accuracy: 0.9965 - val_loss: 0.1415 - val_accuracy: 0.9929 - lr: 1.0000e-04
# Epoch 24/30
# 388/389 [============================>.] - ETA: 0s - loss: 0.1300 - accuracy: 0.9956
# Epoch 24: val_accuracy did not improve from 0.99421
# 389/389 [==============================] - 10s 24ms/step - loss: 0.1299 - accuracy: 0.9957 - val_loss: 0.1383 - val_accuracy: 0.9910 - lr: 1.0000e-04
# Epoch 25/30
# 388/389 [============================>.] - ETA: 0s - loss: 0.1199 - accuracy: 0.9982
# Epoch 25: val_accuracy did not improve from 0.99421
# 389/389 [==============================] - 10s 24ms/step - loss: 0.1198 - accuracy: 0.9982 - val_loss: 0.1310 - val_accuracy: 0.9910 - lr: 1.0000e-04
# Epoch 26/30
# 388/389 [============================>.] - ETA: 0s - loss: 0.1161 - accuracy: 0.9969
# Epoch 26: val_accuracy did not improve from 0.99421
# 389/389 [==============================] - 10s 25ms/step - loss: 0.1160 - accuracy: 0.9969 - val_loss: 0.1261 - val_accuracy: 0.9929 - lr: 1.0000e-04
# Epoch 27/30
# 388/389 [============================>.] - ETA: 0s - loss: 0.1106 - accuracy: 0.9973
# Epoch 27: val_accuracy did not improve from 0.99421
# 389/389 [==============================] - 9s 24ms/step - loss: 0.1106 - accuracy: 0.9973 - val_loss: 0.1235 - val_accuracy: 0.9916 - lr: 1.0000e-04
# Epoch 28/30
# 388/389 [============================>.] - ETA: 0s - loss: 0.1075 - accuracy: 0.9963
# Epoch 28: val_accuracy did not improve from 0.99421
# 389/389 [==============================] - 10s 24ms/step - loss: 0.1075 - accuracy: 0.9963 - val_loss: 0.1157 - val_accuracy: 0.9942 - lr: 1.0000e-04
# Epoch 29/30
# 388/389 [============================>.] - ETA: 0s - loss: 0.1041 - accuracy: 0.9963
# Epoch 29: val_accuracy did not improve from 0.99421
# 389/389 [==============================] - 9s 24ms/step - loss: 0.1041 - accuracy: 0.9963 - val_loss: 0.1134 - val_accuracy: 0.9929 - lr: 1.0000e-04
# Epoch 30/30
# 388/389 [============================>.] - ETA: 0s - loss: 0.0975 - accuracy: 0.9976
# Epoch 30: val_accuracy did not improve from 0.99421
# 389/389 [==============================] - 10s 25ms/step - loss: 0.0976 - accuracy: 0.9974 - val_loss: 0.1117 - val_accuracy: 0.9916 - lr: 1.0000e-04

# %%
training_history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])

# %%
print("\n📈 Training history:\n")

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Accuracy
axes[0].plot(training_history.history['accuracy'], label='Train', linewidth=2, marker='o')
axes[0].plot(training_history.history['val_accuracy'], label='Validation', linewidth=2, marker='s')
axes[0].set_title('Model Accuracy', fontsize=14, fontweight='bold')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Accuracy')
axes[0].legend()
axes[0].grid(True, alpha=0.3)

# Loss
axes[1].plot(training_history.history['loss'], label='Train', linewidth=2, marker='o')
axes[1].plot(training_history.history['val_loss'], label='Validation', linewidth=2, marker='s')
axes[1].set_title('Model Loss', fontsize=14, fontweight='bold')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Loss')
axes[1].legend()
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('Model_acc_model_loss.png', dpi=800)
plt.show()


# Final metrics
best_val_acc = max(training_history.history['val_accuracy'])
best_train_acc = max(training_history.history['accuracy'])
final_val_loss = min(training_history.history['val_loss'])

print(f"\n📊 FINAL METRICS:")
print(f"   Best Train Accuracy: {best_train_acc:.4f} ({best_train_acc*100:.2f}%)")
print(f"   Best Val Accuracy: {best_val_acc:.4f} ({best_val_acc*100:.2f}%)")
print(f"   Best Val Loss: {final_val_loss:.4f}")
print(f"   Target ≥98.5%: {'ACHIEVED ✅' if best_val_acc >= 0.985 else 'IN PROGRESS ⏳'}")
# Out:
# 📈 Training history:
# 📊 FINAL METRICS:
#    Best Train Accuracy: 0.9982 (99.82%)
#    Best Val Accuracy: 0.9942 (99.42%)
#    Best Val Loss: 0.1117
#    Target ≥98.5%: ACHIEVED ✅

# %%
print(max(training_history.history['accuracy']))
print(max(training_history.history['val_accuracy']))
print(min(training_history.history['loss']))
print(min(training_history.history['val_loss']))
# Out:
# 0.9982306361198425
# 0.9942085146903992
# 0.09756680577993393
# 0.11170172691345215

# %%
def evaluate_dataset(model, dataset, class_names, dataset_name="Dataset", cmap="Blues"):
    
    print(f"\n📊 Evaluating model on {dataset_name}...\n")
    pred_probs = model.predict(dataset, verbose=1)
    y_pred = np.argmax(pred_probs, axis=1)

    y_true = tf.concat([y for x, y in dataset], axis=0).numpy()

    # Classification Report
    print("="*80)
    print(f"📋 CLASSIFICATION REPORT ({dataset_name.upper()})")
    print("="*80)
    print(classification_report(y_true, y_pred, target_names=class_names, digits=4))

    # F1 Score
    f1 = f1_score(y_true, y_pred, average='weighted')
    acc = (y_pred == y_true).mean()

    print(f"\n🎯 Weighted F1 Score: {f1:.4f}")
    print(f"📊 Overall Accuracy:  {acc:.4f}")

    # Confusion Matrix
    cm = confusion_matrix(y_true, y_pred)

    plt.figure(figsize=(7,7))
    sns.heatmap(cm, annot=True, fmt='d', cmap=cmap,
                xticklabels=class_names, yticklabels=class_names)
    plt.title(f'Confusion Matrix - {dataset_name}', fontsize=16)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.savefig(f'confusion_matrix_{dataset_name.lower()}.png', dpi=800)
    plt.show()

    return f1, acc


val_f1, val_acc = evaluate_dataset(model, validation_set, class_names, "Validation", "Blues")
test_f1, test_acc = evaluate_dataset(model, test_set, class_names, "Test", "Greens")


print("\n" + "="*80)
print("📊 FINAL SUMMARY")
print("="*80)

print(f"\n🔵 VALIDATION:")
print(f"   Accuracy: {val_acc:.4f}")
print(f"   F1 Score: {val_f1:.4f}")

print(f"\n🟢 TEST:")
print(f"   Accuracy: {test_acc:.4f}")
print(f"   F1 Score: {test_f1:.4f}")

gap = abs(val_f1 - test_f1)

if gap < 0.02:
    print(f"\nGap: {gap:.4f} ✅ Excellent generalization")
elif gap < 0.05:
    print(f"\nGap: {gap:.4f} ⚠️ Acceptable")
else:
    print(f"\nGap: {gap:.4f} ❌ Possible overfitting")

print("="*80)
# Out:
# 📊 Evaluating model on Validation...
#
# 98/98 [==============================] - 2s 16ms/step
# ================================================================================
# 📋 CLASSIFICATION REPORT (VALIDATION)
# ================================================================================
#                           precision    recall  f1-score   support
#
#       Apple___Apple_scab     0.9854    0.9878    0.9866       410
#        Apple___Black_rot     0.9951    0.9951    0.9951       409
# Apple___Cedar_apple_rust     0.9970    0.9853    0.9912       341
#          Apple___healthy     0.9899    0.9975    0.9937       394
#
#                 accuracy                         0.9916      1554
#                macro avg     0.9919    0.9914    0.9916      1554
#             weighted avg     0.9917    0.9916    0.9916      1554
#
#
# 🎯 Weighted F1 Score: 0.9916
# 📊 Overall Accuracy:  0.9916
# 📊 Evaluating model on Test...
#
# 122/122 [==============================] - 2s 19ms/step
# ================================================================================
# 📋 CLASSIFICATION REPORT (TEST)
# ================================================================================
#                           precision    recall  f1-score   support
#
#       Apple___Apple_scab     0.9901    0.9921    0.9911       504
#        Apple___Black_rot     0.9980    0.9960    0.9970       497
# Apple___Cedar_apple_rust     0.9977    0.9932    0.9954       440
#          Apple___healthy     0.9921    0.9960    0.9940       502
#
#                 accuracy                         0.9943      1943
#                macro avg     0.9945    0.9943    0.9944      1943
#             weighted avg     0.9943    0.9943    0.9943      1943
#
#
# 🎯 Weighted F1 Score: 0.9943
# 📊 Overall Accuracy:  0.9943
# ================================================================================
# 📊 FINAL SUMMARY
# ================================================================================
#
# 🔵 VALIDATION:
#    Accuracy: 0.9916
#    F1 Score: 0.9916
#
# 🟢 TEST:
#    Accuracy: 0.9943
#    F1 Score: 0.9943
#
# Gap: 0.0027 ✅ Excellent generalization
# ================================================================================

# %%
plt.figure(figsize=(10, 10))
for image_batch, labels_batch in training_set.take(1):
    for i in range(12):
        ax = plt.subplot(3, 4, i + 1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(class_names[labels_batch[i]])
        plt.axis("off")

# %%
for images_batch, labels_batch in test_set.take(1):
    
    first_image = images_batch[0].numpy().astype('uint8')
    first_label = labels_batch[0].numpy()
    
    print("first image to predict")
    plt.imshow(first_image)
    print("actual label:",class_names[first_label])
    
    batch_prediction = model.predict(images_batch)
    print("predicted label:",class_names[np.argmax(batch_prediction[0])])
# Out:
# first image to predict
# actual label: Apple___Apple_scab
# 1/1 [==============================] - 0s 466ms/step
# predicted label: Apple___Apple_scab

# %%
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(img)  
    img_array = tf.expand_dims(img_array, 0)
    
    predictions = model.predict(img_array)
    
    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence

# %%
plt.figure(figsize=(15, 15))
for images, labels in test_set.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        
        predicted_class, confidence = predict(model, images[i].numpy())
        actual_class = class_names[labels[i]] 
        
        plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class}.\n Confidence: {confidence}%")
        
        plt.axis("off")
# Out:
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 20ms/step

# %%
model.save_weights('Apple_model_weights_final_vg.h5')
model.save('Apple_custom_cnn_best_final_vg.keras')
