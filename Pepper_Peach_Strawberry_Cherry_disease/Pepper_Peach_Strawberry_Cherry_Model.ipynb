# %%
# !nvidia-smi
# Out:
# Sun Feb 15 00:10:29 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 591.86                 Driver Version: 591.86         CUDA Version: 13.1     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4050 ...  WDDM  |   00000000:01:00.0 Off |                  N/A |
# | N/A   42C    P8              2W /  125W |     616MiB /   6141MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A           18688    C+G   ...Browser\Application\brave.exe      N/A      |
# |    0   N/A  N/A           21300    C+G   ...Browser\Application\brave.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras import Sequential
from tensorflow.keras.layers import (
    Dense, Dropout, 
    BatchNormalization, GlobalAveragePooling2D, Input,
    RandomFlip, RandomRotation, RandomZoom, RandomTranslation, 
    RandomContrast, RandomBrightness
)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import (
    EarlyStopping, ReduceLROnPlateau, ModelCheckpoint,
)
from tensorflow.keras.optimizers.schedules import CosineDecay
from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import confusion_matrix,classification_report, f1_score
from tensorflow.keras.utils import image_dataset_from_directory
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.regularizers import l2
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sns

# %%
training_set = image_dataset_from_directory(
    'train',
    image_size=(224, 224),
    batch_size=32,
    color_mode='rgb',
    class_names=None,
    shuffle=True,
    seed = 123,
    validation_split=None,
    subset=None,
    interpolation='bilinear',
    follow_links=False,
    crop_to_aspect_ratio=False
)
# Out:
# Found 14573 files belonging to 8 classes.

# %%
validation_set = image_dataset_from_directory(
    'valid',
    image_size=(224, 224),
    batch_size=32,
    color_mode='rgb',
    class_names=None,
    shuffle=True,
    seed = 123,
    validation_split=0.5,
    subset='training',
    interpolation='bilinear',
    follow_links=False,
    crop_to_aspect_ratio=False
)
# Out:
# Found 3643 files belonging to 8 classes.
# Using 1822 files for training.

# %%
test_set = image_dataset_from_directory(
    'valid',
    image_size=(224, 224),
    batch_size=32,
    color_mode='rgb',
    class_names=None,
    shuffle=True,
    seed = 123,
    validation_split=0.5,
    subset='validation',
    interpolation='bilinear',
    follow_links=False,
    crop_to_aspect_ratio=False
)
# Out:
# Found 3643 files belonging to 8 classes.
# Using 1821 files for validation.

# %%
class_names = training_set.class_names
print(class_names)
# Out:
# ['Cherry_(including_sour)___Powdery_mildew', 'Cherry_(including_sour)___healthy', 'Peach___Bacterial_spot', 'Peach___healthy', 'Pepper,_bell___Bacterial_spot', 'Pepper,_bell___healthy', 'Strawberry___Leaf_scorch', 'Strawberry___healthy']

# %%
print(training_set)
print(validation_set)
print(test_set)
# Out:
# <BatchDataset element_spec=(TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <BatchDataset element_spec=(TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <BatchDataset element_spec=(TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
data_augmentation = Sequential([
    RandomFlip("horizontal_and_vertical"),
    RandomRotation(0.3),
    RandomZoom(0.2),
    RandomTranslation(0.1, 0.1),
    RandomContrast(0.2),
    RandomBrightness(0.2)
])

# %%
AUTOTUNE = tf.data.AUTOTUNE
training_set = training_set.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
validation_set = validation_set.cache().prefetch(buffer_size=AUTOTUNE)
test_set = test_set.cache().prefetch(buffer_size=AUTOTUNE)

# %%
training_set = training_set.map(lambda x, y: (data_augmentation(x, training=True), y))
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2 cause Input "contrast_factor" of op 'AdjustContrastv2' expected to be loop invariant.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2 cause Input "contrast_factor" of op 'AdjustContrastv2' expected to be loop invariant.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.

# %%
num_classes = len(class_names)
input_shape = (224, 224, 3)
    
base_model = MobileNetV2(
    input_shape=input_shape,
    include_top=False,
    weights='imagenet',  
    alpha=1.0 
)

base_model.trainable = False

inputs = Input(shape=input_shape)
    
x = tf.keras.applications.mobilenet_v2.preprocess_input(inputs)
    
x = base_model(x, training=False)
x = GlobalAveragePooling2D()(x)
x = BatchNormalization()(x)
x = Dropout(0.3)(x)
    
x = Dense(128, activation='relu', kernel_regularizer=l2(0.001))(x)
x = BatchNormalization()(x)
x = Dropout(0.2)(x)
    
outputs = Dense(num_classes, activation='softmax', dtype='float32', name='predictions')(x)
    
model = Model(inputs, outputs, name='MobileNetV2')

# %%
model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss=SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)

# %%
model.build(input_shape=(None, 224, 224, 3))

# %%
model.summary()
# Out:
# Model: "MobileNetV2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.math.truediv (TFOpLambda  (None, 224, 224, 3)      0
#  )
#
#  tf.math.subtract (TFOpLambd  (None, 224, 224, 3)      0
#  a)
#
#  mobilenetv2_1.00_224 (Funct  (None, 7, 7, 1280)       2257984
#  ional)
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  batch_normalization (BatchN  (None, 1280)             5120
#  ormalization)
#
#  dropout (Dropout)           (None, 1280)              0
#
#  dense (Dense)               (None, 128)               163968
#
#  batch_normalization_1 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  predictions (Dense)         (None, 8)                 1032
#
# =================================================================
# Total params: 2,428,616
# Trainable params: 167,816
# Non-trainable params: 2,260,800
# _________________________________________________________________

# %%
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=6,
    restore_best_weights=True,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    min_lr=1e-7,
    verbose=1
)

checkpoint = ModelCheckpoint(
    'Apple_custom_cnn_best_final.keras',
    monitor='val_accuracy',
    save_best_only=True,
    verbose=1
)

callbacks = [early_stop, reduce_lr, checkpoint]

# %%
training_history = model.fit(
    training_set,
    validation_data=validation_set,
    epochs=30,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/30
# 456/456 [==============================] - ETA: 0s - loss: 1.0039 - accuracy: 0.7476
# Epoch 1: val_accuracy improved from -inf to 0.92810, saving model to Apple_custom_cnn_best_final.keras
# 456/456 [==============================] - 124s 241ms/step - loss: 1.0039 - accuracy: 0.7476 - val_loss: 0.4892 - val_accuracy: 0.9281 - lr: 1.0000e-04
# Epoch 2/30
# 456/456 [==============================] - ETA: 0s - loss: 0.4935 - accuracy: 0.9155
# Epoch 2: val_accuracy improved from 0.92810 to 0.95225, saving model to Apple_custom_cnn_best_final.keras
# 456/456 [==============================] - 104s 228ms/step - loss: 0.4935 - accuracy: 0.9155 - val_loss: 0.4003 - val_accuracy: 0.9523 - lr: 1.0000e-04
# Epoch 3/30
# 456/456 [==============================] - ETA: 0s - loss: 0.4109 - accuracy: 0.9400
# Epoch 3: val_accuracy improved from 0.95225 to 0.95664, saving model to Apple_custom_cnn_best_final.keras
# 456/456 [==============================] - 102s 223ms/step - loss: 0.4109 - accuracy: 0.9400 - val_loss: 0.3591 - val_accuracy: 0.9566 - lr: 1.0000e-04
# Epoch 4/30
# 456/456 [==============================] - ETA: 0s - loss: 0.3715 - accuracy: 0.9519
# Epoch 4: val_accuracy improved from 0.95664 to 0.96103, saving model to Apple_custom_cnn_best_final.keras
# 456/456 [==============================] - 104s 229ms/step - loss: 0.3715 - accuracy: 0.9519 - val_loss: 0.3439 - val_accuracy: 0.9610 - lr: 1.0000e-04
# Epoch 5/30
# 456/456 [==============================] - ETA: 0s - loss: 0.3494 - accuracy: 0.9564
# Epoch 5: val_accuracy improved from 0.96103 to 0.96762, saving model to Apple_custom_cnn_best_final.keras
# 456/456 [==============================] - 101s 222ms/step - loss: 0.3494 - accuracy: 0.9564 - val_loss: 0.3131 - val_accuracy: 0.9676 - lr: 1.0000e-04
# Epoch 6/30
# 456/456 [==============================] - ETA: 0s - loss: 0.3318 - accuracy: 0.9592
# Epoch 6: val_accuracy improved from 0.96762 to 0.97146, saving model to Apple_custom_cnn_best_final.keras
# 456/456 [==============================] - 102s 223ms/step - loss: 0.3318 - accuracy: 0.9592 - val_loss: 0.2934 - val_accuracy: 0.9715 - lr: 1.0000e-04
# Epoch 7/30
# 456/456 [==============================] - ETA: 0s - loss: 0.3136 - accuracy: 0.9635
# Epoch 7: val_accuracy improved from 0.97146 to 0.97420, saving model to Apple_custom_cnn_best_final.keras
# 456/456 [==============================] - 105s 230ms/step - loss: 0.3136 - accuracy: 0.9635 - val_loss: 0.2803 - val_accuracy: 0.9742 - lr: 1.0000e-04
# Epoch 8/30
# 456/456 [==============================] - ETA: 0s - loss: 0.3007 - accuracy: 0.9648
# Epoch 8: val_accuracy did not improve from 0.97420
# 456/456 [==============================] - 104s 228ms/step - loss: 0.3007 - accuracy: 0.9648 - val_loss: 0.2742 - val_accuracy: 0.9726 - lr: 1.0000e-04
# Epoch 9/30
# 456/456 [==============================] - ETA: 0s - loss: 0.2897 - accuracy: 0.9654
# Epoch 9: val_accuracy improved from 0.97420 to 0.97695, saving model to Apple_custom_cnn_best_final.keras
# 456/456 [==============================] - 108s 238ms/step - loss: 0.2897 - accuracy: 0.9654 - val_loss: 0.2591 - val_accuracy: 0.9769 - lr: 1.0000e-04
# Epoch 10/30
# 456/456 [==============================] - ETA: 0s - loss: 0.2775 - accuracy: 0.9666
# Epoch 10: val_accuracy improved from 0.97695 to 0.97750, saving model to Apple_custom_cnn_best_final.keras
# 456/456 [==============================] - 108s 236ms/step - loss: 0.2775 - accuracy: 0.9666 - val_loss: 0.2420 - val_accuracy: 0.9775 - lr: 1.0000e-04
# Epoch 11/30
# 456/456 [==============================] - ETA: 0s - loss: 0.2582 - accuracy: 0.9723
# Epoch 11: val_accuracy improved from 0.97750 to 0.97914, saving model to Apple_custom_cnn_best_final.keras
# 456/456 [==============================] - 104s 228ms/step - loss: 0.2582 - accuracy: 0.9723 - val_loss: 0.2358 - val_accuracy: 0.9791 - lr: 1.0000e-04
# Epoch 12/30
# 456/456 [==============================] - ETA: 0s - loss: 0.2534 - accuracy: 0.9715
# Epoch 12: val_accuracy did not improve from 0.97914
# 456/456 [==============================] - 103s 227ms/step - loss: 0.2534 - accuracy: 0.9715 - val_loss: 0.2306 - val_accuracy: 0.9791 - lr: 1.0000e-04
# Epoch 13/30
# 456/456 [==============================] - ETA: 0s - loss: 0.2435 - accuracy: 0.9722
# Epoch 13: val_accuracy improved from 0.97914 to 0.98134, saving model to Apple_custom_cnn_best_final.keras
# 456/456 [==============================] - 99s 217ms/step - loss: 0.2435 - accuracy: 0.9722 - val_loss: 0.2170 - val_accuracy: 0.9813 - lr: 1.0000e-04
# Epoch 14/30
# 456/456 [==============================] - ETA: 0s - loss: 0.2340 - accuracy: 0.9730
# Epoch 14: val_accuracy improved from 0.98134 to 0.98244, saving model to Apple_custom_cnn_best_final.keras
# 456/456 [==============================] - 104s 229ms/step - loss: 0.2340 - accuracy: 0.9730 - val_loss: 0.2086 - val_accuracy: 0.9824 - lr: 1.0000e-04
# Epoch 15/30
# 456/456 [==============================] - ETA: 0s - loss: 0.2237 - accuracy: 0.9742
# Epoch 15: val_accuracy did not improve from 0.98244
# 456/456 [==============================] - 99s 217ms/step - loss: 0.2237 - accuracy: 0.9742 - val_loss: 0.2037 - val_accuracy: 0.9813 - lr: 1.0000e-04
# Epoch 16/30
# 456/456 [==============================] - ETA: 0s - loss: 0.2185 - accuracy: 0.9728
# Epoch 16: val_accuracy improved from 0.98244 to 0.98408, saving model to Apple_custom_cnn_best_final.keras
# 456/456 [==============================] - 99s 218ms/step - loss: 0.2185 - accuracy: 0.9728 - val_loss: 0.1981 - val_accuracy: 0.9841 - lr: 1.0000e-04
# Epoch 17/30
# 456/456 [==============================] - ETA: 0s - loss: 0.2120 - accuracy: 0.9736
# Epoch 17: val_accuracy did not improve from 0.98408
# 456/456 [==============================] - 115s 252ms/step - loss: 0.2120 - accuracy: 0.9736 - val_loss: 0.1849 - val_accuracy: 0.9835 - lr: 1.0000e-04
# Epoch 18/30
# 456/456 [==============================] - ETA: 0s - loss: 0.1998 - accuracy: 0.9764
# Epoch 18: val_accuracy did not improve from 0.98408
# 456/456 [==============================] - 116s 254ms/step - loss: 0.1998 - accuracy: 0.9764 - val_loss: 0.1835 - val_accuracy: 0.9797 - lr: 1.0000e-04
# Epoch 19/30
# 456/456 [==============================] - ETA: 0s - loss: 0.1937 - accuracy: 0.9752
# Epoch 19: val_accuracy improved from 0.98408 to 0.98463, saving model to Apple_custom_cnn_best_final.keras
# 456/456 [==============================] - 106s 232ms/step - loss: 0.1937 - accuracy: 0.9752 - val_loss: 0.1736 - val_accuracy: 0.9846 - lr: 1.0000e-04
# Epoch 20/30
# 456/456 [==============================] - ETA: 0s - loss: 0.1869 - accuracy: 0.9771
# Epoch 20: val_accuracy did not improve from 0.98463
# 456/456 [==============================] - 104s 227ms/step - loss: 0.1869 - accuracy: 0.9771 - val_loss: 0.1671 - val_accuracy: 0.9830 - lr: 1.0000e-04
# Epoch 21/30
# 456/456 [==============================] - ETA: 0s - loss: 0.1799 - accuracy: 0.9778
# Epoch 21: val_accuracy did not improve from 0.98463
# 456/456 [==============================] - 105s 229ms/step - loss: 0.1799 - accuracy: 0.9778 - val_loss: 0.1640 - val_accuracy: 0.9830 - lr: 1.0000e-04
# Epoch 22/30
# 456/456 [==============================] - ETA: 0s - loss: 0.1792 - accuracy: 0.9771
# Epoch 22: val_accuracy did not improve from 0.98463
# 456/456 [==============================] - 103s 225ms/step - loss: 0.1792 - accuracy: 0.9771 - val_loss: 0.1674 - val_accuracy: 0.9819 - lr: 1.0000e-04
# Epoch 23/30
# 456/456 [==============================] - ETA: 0s - loss: 0.1706 - accuracy: 0.9776
# Epoch 23: val_accuracy improved from 0.98463 to 0.98573, saving model to Apple_custom_cnn_best_final.keras
# 456/456 [==============================] - 103s 226ms/step - loss: 0.1706 - accuracy: 0.9776 - val_loss: 0.1523 - val_accuracy: 0.9857 - lr: 1.0000e-04
# Epoch 24/30
# 456/456 [==============================] - ETA: 0s - loss: 0.1690 - accuracy: 0.9774
# Epoch 24: val_accuracy did not improve from 0.98573
# 456/456 [==============================] - 102s 224ms/step - loss: 0.1690 - accuracy: 0.9774 - val_loss: 0.1525 - val_accuracy: 0.9824 - lr: 1.0000e-04
# Epoch 25/30
# 456/456 [==============================] - ETA: 0s - loss: 0.1615 - accuracy: 0.9792
# Epoch 25: val_accuracy did not improve from 0.98573
# 456/456 [==============================] - 104s 229ms/step - loss: 0.1615 - accuracy: 0.9792 - val_loss: 0.1509 - val_accuracy: 0.9830 - lr: 1.0000e-04
# Epoch 26/30
# 456/456 [==============================] - ETA: 0s - loss: 0.1560 - accuracy: 0.9796
# Epoch 26: val_accuracy did not improve from 0.98573
# 456/456 [==============================] - 112s 245ms/step - loss: 0.1560 - accuracy: 0.9796 - val_loss: 0.1455 - val_accuracy: 0.9835 - lr: 1.0000e-04
# Epoch 27/30
# 456/456 [==============================] - ETA: 0s - loss: 0.1504 - accuracy: 0.9804
# Epoch 27: val_accuracy did not improve from 0.98573
# 456/456 [==============================] - 107s 236ms/step - loss: 0.1504 - accuracy: 0.9804 - val_loss: 0.1461 - val_accuracy: 0.9819 - lr: 1.0000e-04
# Epoch 28/30
# 456/456 [==============================] - ETA: 0s - loss: 0.1475 - accuracy: 0.9802
# Epoch 28: val_accuracy did not improve from 0.98573
# 456/456 [==============================] - 102s 225ms/step - loss: 0.1475 - accuracy: 0.9802 - val_loss: 0.1464 - val_accuracy: 0.9775 - lr: 1.0000e-04
# Epoch 29/30
# 456/456 [==============================] - ETA: 0s - loss: 0.1476 - accuracy: 0.9798
# Epoch 29: val_accuracy did not improve from 0.98573
# 456/456 [==============================] - 104s 228ms/step - loss: 0.1476 - accuracy: 0.9798 - val_loss: 0.1342 - val_accuracy: 0.9835 - lr: 1.0000e-04
# Epoch 30/30
# 456/456 [==============================] - ETA: 0s - loss: 0.1406 - accuracy: 0.9809
# Epoch 30: val_accuracy did not improve from 0.98573
# 456/456 [==============================] - 102s 223ms/step - loss: 0.1406 - accuracy: 0.9809 - val_loss: 0.1447 - val_accuracy: 0.9797 - lr: 1.0000e-04

# %%
training_history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])

# %%
print("\n📈 Training history:\n")

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Accuracy
axes[0].plot(training_history.history['accuracy'], label='Train', linewidth=2, marker='o')
axes[0].plot(training_history.history['val_accuracy'], label='Validation', linewidth=2, marker='s')
axes[0].set_title('Model Accuracy', fontsize=14, fontweight='bold')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Accuracy')
axes[0].legend()
axes[0].grid(True, alpha=0.3)

# Loss
axes[1].plot(training_history.history['loss'], label='Train', linewidth=2, marker='o')
axes[1].plot(training_history.history['val_loss'], label='Validation', linewidth=2, marker='s')
axes[1].set_title('Model Loss', fontsize=14, fontweight='bold')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Loss')
axes[1].legend()
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('Model_acc_model_loss.png', dpi=800)
plt.show()


# Final metrics
best_val_acc = max(training_history.history['val_accuracy'])
best_train_acc = max(training_history.history['accuracy'])
final_val_loss = min(training_history.history['val_loss'])

print(f"\n📊 FINAL METRICS:")
print(f"   Best Train Accuracy: {best_train_acc:.4f} ({best_train_acc*100:.2f}%)")
print(f"   Best Val Accuracy: {best_val_acc:.4f} ({best_val_acc*100:.2f}%)")
print(f"   Best Val Loss: {final_val_loss:.4f}")
print(f"   Target ≥98.5%: {'ACHIEVED ✅' if best_val_acc >= 0.985 else 'IN PROGRESS ⏳'}")
# Out:
# 📈 Training history:
# 📊 FINAL METRICS:
#    Best Train Accuracy: 0.9809 (98.09%)
#    Best Val Accuracy: 0.9857 (98.57%)
#    Best Val Loss: 0.1342
#    Target ≥98.5%: ACHIEVED ✅

# %%
print(max(training_history.history['accuracy']))
print(max(training_history.history['val_accuracy']))
print(min(training_history.history['loss']))
print(min(training_history.history['val_loss']))
# Out:
# 0.9808549880981445
# 0.985729992389679
# 0.14055465161800385
# 0.13421916961669922

# %%
def evaluate_dataset(model, dataset, class_names, dataset_name="Dataset", cmap="Blues"):
    
    print(f"\n📊 Evaluating model on {dataset_name}...\n")
    pred_probs = model.predict(dataset, verbose=1)
    y_pred = np.argmax(pred_probs, axis=1)

    y_true = tf.concat([y for x, y in dataset], axis=0).numpy()

    # Classification Report
    print("="*80)
    print(f"📋 CLASSIFICATION REPORT ({dataset_name.upper()})")
    print("="*80)
    print(classification_report(y_true, y_pred, target_names=class_names, digits=4))

    # F1 Score
    f1 = f1_score(y_true, y_pred, average='weighted')
    acc = (y_pred == y_true).mean()

    print(f"\n🎯 Weighted F1 Score: {f1:.4f}")
    print(f"📊 Overall Accuracy:  {acc:.4f}")

    # Confusion Matrix
    cm = confusion_matrix(y_true, y_pred)

    plt.figure(figsize=(7,7))
    sns.heatmap(cm, annot=True, fmt='d', cmap=cmap,
                xticklabels=class_names, yticklabels=class_names)
    plt.title(f'Confusion Matrix - {dataset_name}', fontsize=16)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.savefig(f'confusion_matrix_{dataset_name.lower()}.png', dpi=800)
    plt.show()

    return f1, acc


val_f1, val_acc = evaluate_dataset(model, validation_set, class_names, "Validation", "Blues")
test_f1, test_acc = evaluate_dataset(model, test_set, class_names, "Test", "Greens")


print("\n" + "="*80)
print("📊 FINAL SUMMARY")
print("="*80)

print(f"\n🔵 VALIDATION:")
print(f"   Accuracy: {val_acc:.4f}")
print(f"   F1 Score: {val_f1:.4f}")

print(f"\n🟢 TEST:")
print(f"   Accuracy: {test_acc:.4f}")
print(f"   F1 Score: {test_f1:.4f}")

gap = abs(val_f1 - test_f1)

if gap < 0.02:
    print(f"\nGap: {gap:.4f} ✅ Excellent generalization")
elif gap < 0.05:
    print(f"\nGap: {gap:.4f} ⚠️ Acceptable")
else:
    print(f"\nGap: {gap:.4f} ❌ Possible overfitting")

print("="*80)
# Out:
# 📊 Evaluating model on Validation...
#
# 57/57 [==============================] - 4s 38ms/step
# ================================================================================
# 📋 CLASSIFICATION REPORT (VALIDATION)
# ================================================================================
#                                           precision    recall  f1-score   support
#
# Cherry_(including_sour)___Powdery_mildew     1.0000    0.9469    0.9727       207
#        Cherry_(including_sour)___healthy     0.9956    1.0000    0.9978       226
#                   Peach___Bacterial_spot     0.9957    0.9957    0.9957       233
#                          Peach___healthy     0.9819    0.9954    0.9886       218
#            Pepper,_bell___Bacterial_spot     0.8889    1.0000    0.9412       224
#                   Pepper,_bell___healthy     1.0000    0.9059    0.9506       255
#                 Strawberry___Leaf_scorch     1.0000    1.0000    1.0000       222
#                     Strawberry___healthy     0.9875    1.0000    0.9937       237
#
#                                 accuracy                         0.9797      1822
#                                macro avg     0.9812    0.9805    0.9800      1822
#                             weighted avg     0.9815    0.9797    0.9798      1822
#
#
# 🎯 Weighted F1 Score: 0.9798
# 📊 Overall Accuracy:  0.9797
# 📊 Evaluating model on Test...
#
# 57/57 [==============================] - 3s 40ms/step
# ================================================================================
# 📋 CLASSIFICATION REPORT (TEST)
# ================================================================================
#                                           precision    recall  f1-score   support
#
# Cherry_(including_sour)___Powdery_mildew     1.0000    0.9439    0.9712       214
#        Cherry_(including_sour)___healthy     1.0000    1.0000    1.0000       230
#                   Peach___Bacterial_spot     0.9912    0.9912    0.9912       226
#                          Peach___healthy     0.9907    0.9953    0.9930       214
#            Pepper,_bell___Bacterial_spot     0.9134    0.9961    0.9529       254
#                   Pepper,_bell___healthy     0.9867    0.9174    0.9507       242
#                 Strawberry___Leaf_scorch     1.0000    0.9955    0.9977       222
#                     Strawberry___healthy     0.9733    1.0000    0.9865       219
#
#                                 accuracy                         0.9797      1821
#                                macro avg     0.9819    0.9799    0.9804      1821
#                             weighted avg     0.9807    0.9797    0.9797      1821
#
#
# 🎯 Weighted F1 Score: 0.9797
# 📊 Overall Accuracy:  0.9797
# ================================================================================
# 📊 FINAL SUMMARY
# ================================================================================
#
# 🔵 VALIDATION:
#    Accuracy: 0.9797
#    F1 Score: 0.9798
#
# 🟢 TEST:
#    Accuracy: 0.9797
#    F1 Score: 0.9797
#
# Gap: 0.0001 ✅ Excellent generalization
# ================================================================================

# %%
plt.figure(figsize=(10, 10))
for image_batch, labels_batch in training_set.take(1):
    for i in range(12):
        ax = plt.subplot(3, 4, i + 1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(class_names[labels_batch[i]])
        plt.axis("off")

# %%
for images_batch, labels_batch in test_set.take(1):
    
    first_image = images_batch[0].numpy().astype('uint8')
    first_label = labels_batch[0].numpy()
    
    print("first image to predict")
    plt.imshow(first_image)
    print("actual label:",class_names[first_label])
    
    batch_prediction = model.predict(images_batch)
    print("predicted label:",class_names[np.argmax(batch_prediction[0])])
# Out:
# first image to predict
# actual label: Strawberry___Leaf_scorch
# 1/1 [==============================] - 0s 468ms/step
# predicted label: Strawberry___Leaf_scorch

# %%
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(img)  
    img_array = tf.expand_dims(img_array, 0)
    
    predictions = model.predict(img_array)
    
    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence

# %%
plt.figure(figsize=(15, 15))
for images, labels in test_set.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        
        predicted_class, confidence = predict(model, images[i].numpy())
        actual_class = class_names[labels[i]] 
        
        plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class}.\n Confidence: {confidence}%")
        
        plt.axis("off")
# Out:
# 1/1 [==============================] - 1s 535ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step

# %%
model.save_weights('Mixed_model_weights_final_vg.h5')
model.save('Mixed_custom_cnn_best_final_vg.keras')
